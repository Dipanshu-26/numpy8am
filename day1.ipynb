# %% [markdown]
# This is my first notebook

# %%
print("hello")
# Out:
# hello

# %%
print("python2")
# Out:
# python2

# %%
a=10
b=20
b
a
# Out:
# 10

# %%
#!pip install jupyter ipykernel

# %%
import sys
print(sys.executable)
# Out:
# d:\batches-folder\python\numpy8am\.venv\Scripts\python.exe

# %% [markdown]
# array -- list -- slow
# numpy  -- array

# %%
#find average
temperature = [32.2, 31.5,33,7,32.8,35.1]         #list

total =0 
for temp in temperature:
    total+=temp     # total = total+temp

average = total/len(temperature)

# %%
average
# Out:
# 28.599999999999998

# %%
#!pip install numpy
# Out:
# ...
#   Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl (12.6 MB)
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
# how to define array with numpy 
temperatures = np.array([32.2, 31.5,33,7,32.8,35.1])
temperatures
# Out:
# array([32.2, 31.5, 33. ,  7. , 32.8, 35.1])

# %%
avg_temp = np.mean(temperatures)
print(avg_temp)
# Out:
# 28.599999999999998

# %%
py_list=[1,2,3,4,5,6,7]
py_list
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
type(py_list)
# Out:
# list

# %%
np_array=np.array([1,2,3,4,5,6,7,8])
np_array
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
type(np_array)
# Out:
# numpy.ndarray

# %%
np_array.dtype
# Out:
# dtype('int64')

# %%
np_array2=np.array([1.2,3.4,5.6,6.7])
np_array2
# Out:
# array([1.2, 3.4, 5.6, 6.7])

# %%
np_array2.dtype
# Out:
# dtype('float64')

# %% [markdown]
# zeros()<br>
# once()<br>
# fill()<br>
# empty()<br>

# %%
arr_z= np.zeros(3)
arr_z
# Out:
# array([0., 0., 0.])

# %%
arr_z.dtype
# Out:
# dtype('float64')

# %%
arr_z1=np.zeros(5, dtype=int)
arr_z1
# Out:
# array([0, 0, 0, 0, 0])

# %%
arr_z1.dtype
# Out:
# dtype('int64')

# %%
#                r  c
arr_z2=np.zeros((2,3))
arr_z2
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
arr_z2=np.zeros((3,2))
arr_z2
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])
